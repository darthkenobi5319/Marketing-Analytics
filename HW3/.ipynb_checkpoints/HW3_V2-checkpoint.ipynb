# %%
import numpy as np
import pandas as pd
import json

# %%
df = pd.read_csv("attribution_allocation_student_data.csv")

# %%
df.head()
# Out:
#    convert_TF         touch_1  touch_2         touch_3 touch_4 touch_5  tier
# 0        True           email   direct          social     NaN     NaN     1
# 1        True          social   direct  organic_search     NaN     NaN     1
# 2        True  organic_search  display          social     NaN     NaN     1
# 3        True          social   direct             NaN     NaN     NaN     1
# 4        True          social  display          direct     NaN     NaN     1

# %%
df.tier.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df = df.fillna('none')

# %%
df.head()
# Out:
#    convert_TF         touch_1  touch_2         touch_3 touch_4 touch_5  tier
# 0        True           email   direct          social    none    none     1
# 1        True          social   direct  organic_search    none    none     1
# 2        True  organic_search  display          social    none    none     1
# 3        True          social   direct            none    none    none     1
# 4        True          social  display          direct    none    none     1

# %%
df_channel = pd.read_csv("channel_spend_student_data.csv")

# %%
df_channel = df_channel.drop(3)

# %%
newdf = list()
for i in range(len(df_channel)):
    temp = json.loads(df_channel['spend by channel'][i].replace("\'", "\""))
    temp['tier'] = (i+1)
    newdf.append(temp)
newdf
# Out:
# [{'social': 50,
#   'organic_search': 0,
#   'referral': 50,
#   'email': 50,
#   'paid_search': 50,
#   'display': 50,
#   'direct': 0,
#   'tier': 1},
#  {'social': 100,
#   'organic_search': 0,
#   'referral': 100,
#   'email': 100,
#   'paid_search': 100,
#   'display': 100,
#   'direct': 0,
#   'tier': 2},
#  {'social': 150,
#   'organic_search': 0,
#   'referral': 150,
#   'email': 150,
#   'paid_search': 150,
#   'display': 150,
#   'direct': 0,
#   'tier': 3}]

# %%
df_channel = pd.DataFrame(newdf)

# %%
df1 = pd.merge(df, df_channel,how='left', on='tier')

# %%
df1.head()
# Out:
#    convert_TF         touch_1  touch_2         touch_3 touch_4 touch_5  tier  \
# 0        True           email   direct          social    none    none     1
# 1        True          social   direct  organic_search    none    none     1
# 2        True  organic_search  display          social    none    none     1
# 3        True          social   direct            none    none    none     1
# 4        True          social  display          direct    none    none     1
#
#    social  organic_search  referral  email  paid_search  display  direct
# 0      50               0        50     50           50       50       0
# 1      50               0        50     50           50       50       0
# 2      50               0        50     50           50       50       0
# 3      50               0        50     50           50       50       0
# 4      50               0        50     50           50       50       0

# %%
df.iloc[0,:]['touch_1']
# Out:
# 'email'

# %%
len(df)
# Out:
# 218412

# %%
df['convert_TF'].value_counts()
# Out:
# False    216034
# True       2378
# Name: convert_TF, dtype: int64

# %% [markdown]
# ## Last interaction

# %%
# This function takes a row accessed by dataframe's iloc, and returns the last contact
#@param: entry: a single entry of the dataframe. Must be a return value from the iloc function
#@return: a tuple. the last contact. None if not applicable. second attribute is count, and another attribute is cost
def find_last_contact(entry):
    if entry['convert_TF']:
        if entry['touch_5'] == 'none':
            if entry['touch_4'] == 'none':
                if entry['touch_3'] == 'none':
                    if entry['touch_2'] == 'none':
                        if entry['touch_1'] == 'none':
                            return None,[0],[0]
                        else:
                            list_channel = list()
                            list_number = list()
                            list_channel.append(entry['touch_1'])
                            list_number.append(1)
                            return list_channel,list_number,[entry[entry['touch_1']]]
                    else:
                        list_channel = list()
                        list_number = list()
                        list_channel.append(entry['touch_2'])
                        list_channel.append(entry['touch_1'])
                        list_number.append(1)
                        list_number.append(0)
                        cost = [entry[entry['touch_2']],entry[entry['touch_1']]]
                        return list_channel,list_number,cost
                else:
                    list_channel = list()
                    list_number = list()
                    list_channel.append(entry['touch_3'])
                    list_channel.append(entry['touch_2'])
                    list_channel.append(entry['touch_1'])
                    list_number.append(1)
                    list_number.append(0)
                    list_number.append(0)
                    cost = [entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
                    return list_channel,list_number,cost
            else:
                list_channel = list()
                list_number = list()
                list_channel.append(entry['touch_4'])
                list_channel.append(entry['touch_3'])
                list_channel.append(entry['touch_2'])
                list_channel.append(entry['touch_1'])
                list_number.append(1)
                list_number.append(0)
                list_number.append(0)
                list_number.append(0)
                cost = [entry[entry['touch_4']],entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
                return list_channel,list_number,cost
        else:
            list_channel = list()
            list_number = list()
            list_channel.append(entry['touch_5'])
            list_channel.append(entry['touch_4'])
            list_channel.append(entry['touch_3'])
            list_channel.append(entry['touch_2'])
            list_channel.append(entry['touch_1'])
            list_number.append(1)
            list_number.append(0)
            list_number.append(0)
            list_number.append(0)
            list_number.append(0)
            cost = [entry[entry['touch_5']],entry[entry['touch_4']],entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
            return list_channel,list_number,cost
    else:
        return None,[0],[0]

# %%
list_of_entry_last_user = list()
list_of_entry_last = list()
for i in range(len(df)):
    entry = df1.iloc[i,:]
    list_of_entry_last.append(find_last_contact(entry))

# %%
list_of_entry_last
# Out:
# [(['social', 'direct', 'email'], [1, 0, 0], [50, 0, 50]),
#  (['organic_search', 'direct', 'social'], [1, 0, 0], [0, 0, 50]),
#  (['social', 'display', 'organic_search'], [1, 0, 0], [50, 50, 0]),
#  (['direct', 'social'], [1, 0], [0, 50]),
#  (['direct', 'display', 'social'], [1, 0, 0], [0, 50, 50]),
#  (['display', 'social'], [1, 0], [50, 50]),
#  (['social'], [1], [50]),
#  (['direct', 'social', 'display', 'organic_search'],
#   [1, 0, 0, 0],
#   [0, 50, 50, 0]),
#  (['social'], [1], [50]),
#  (['social'], [1], [50]),
#  (['organic_search', 'email', 'social'], [1, 0, 0], [0, 50, 50]),
#  (['organic_search', 'social'], [1, 0], [0, 50]),
#  (['social', 'organic_search', 'direct'], [1, 0, 0], [50, 0, 0]),
#  (['organic_search', 'social', 'direct'], [1, 0, 0], [0, 50, 0]),
#  (['social', 'display'], [1, 0], [50, 50]),
#  (['direct', 'display', 'social'], [1, 0, 0], [0, 50, 50]),
#  (['social', 'organic_search'], [1, 0], [50, 0]),
#  (['direct', 'social', 'display'], [1, 0, 0], [0, 50, 50]),
#  (['social', 'display'], [1, 0], [50, 50]),
#  (['organic_search', 'direct', 'social'], [1, 0, 0], [0, 0, 50]),
#  (['organic_search', 'display', 'email', 'social'],
#   [1, 0, 0, 0],
#   [0, 50, 50, 50]),
#  (['email', 'organic_search', 'social'], [1, 0, 0], [50, 0, 50]),
#  (['direct', 'display', 'organic_search', 'email', 'social'],
#   [1, 0, 0, 0, 0],
#   [0, 50, 0, 50, 50]),
#  (['social', 'direct', 'email'], [1, 0, 0], [50, 0, 50]),
#  (['email', 'social', 'direct'], [1, 0, 0], [50, 50, 0]),
#  (['organic_search', 'display', 'direct', 'social'],
#   [1, 0, 0, 0],
#   [0, 50, 0, 50]),
#  (['display', 'social', 'organic_search'], [1, 0, 0], [50, 50, 0]),
#  (['social', 'direct', 'email', 'organic_search', 'display'],
#   [1, 0, 0, 0, 0],
#   [50, 0, 50, 0, 50]),
#  (['social', 'direct', 'organic_search'], [1, 0, 0], [50, 0, 0]),
#  (['direct', 'organic_search', 'display', 'social', 'email'],
#   [1, 0, 0, 0, 0],
#   [0, 0, 50, 50, 50]),
#  (['direct', 'organic_search', 'email', 'social', 'display'],
#   [1, 0, 0, 0, 0],
#   [0, 0, 50, 50, 50]),
#  (['organic_search', 'direct', 'social'], [1, 0, 0], [0, 0, 50]),
#  (['display', 'social', 'email'], [1, 0, 0], [50, 50, 50]),
#  (['social', 'direct'], [1, 0], [50, 0]),
#  (['display', 'social', 'direct'], [1, 0, 0], [50, 50, 0]),
#  (['social'], [1], [50]),
#  (['display', 'social', 'organic_search'], [1, 0, 0], [50, 50, 0]),
#  (['direct', 'social', 'email'], [1, 0, 0], [0, 50, 50]),
#  (['email', 'organic_search', 'social', 'display', 'direct'],
#   [1, 0, 0, 0, 0],
#   [50, 0, 50, 50, 0]),
#  (['organic_search', 'social', 'email', 'direct', 'display'],
#   [1, 0, 0, 0, 0],
#   [0, 50, 50, 0, 50]),
#  (['organic_search', 'direct', 'social'], [1, 0, 0], [0, 0, 50]),
#  (['organic_search', 'social', 'direct', 'display', 'email'],
#   [1, 0, 0, 0, 0],
#   [0, 50, 0, 50, 50]),
#  (['organic_search', 'direct', 'social', 'email'],
#   [1, 0, 0, 0],
#   [0, 0, 50, 50]),
#  (['direct', 'email', 'social', 'display', 'organic_search'],
#   [1, 0, 0, 0, 0],
#   [0, 50, 50, 50, 0]),
#  (['display', 'social'], [1, 0], [50, 50]),
#  (['social'], [1], [50]),
#  (['social', 'display'], [1, 0], [50, 50]),
#  (['social'], [1], [50]),
#  (['social', 'organic_search', 'display'], [1, 0, 0], [50, 0, 50]),
#  (['social', 'direct', 'email', 'display', 'organic_search'],
#   [1, 0, 0, 0, 0],
#   [50, 0, 50, 50, 0]),
#  (['social', 'organic_search', 'direct'], [1, 0, 0], [50, 0, 0]),
#  (['organic_search', 'email', 'display', 'social', 'direct'],
#   [1, 0, 0, 0, 0],
#   [0, 50, 50, 50, 0]),
#  (['display', 'social', 'organic_search'], [1, 0, 0], [50, 50, 0]),
#  (['display', 'social', 'organic_search', 'direct'],
#   [1, 0, 0, 0],
#   [50, 50, 0, 0]),
#  (['email', 'direct', 'display', 'social'], [1, 0, 0, 0], [50, 0, 50, 50]),
#  (['social', 'direct'], [1, 0], [50, 0]),
#  (['organic_search', 'direct', 'social', 'display'],
#   [1, 0, 0, 0],
#   [0, 0, 50, 50]),
#  (['display', 'organic_search', 'social'], [1, 0, 0], [50, 0, 50]),
#  (['email', 'direct', 'display', 'social', 'organic_search'],
#   [1, 0, 0, 0, 0],
#   [50, 0, 50, 50, 0]),
#  (['display', 'social'], [1, 0], [50, 50]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  ...]

# %%
len(list_of_entry_last)
# Out:
# 218412

# %%
# This function takes a list of entry, each element is a tuple shaped like (channel,count,cost)
# And prints out count, cost, and CAC
#@param: list_of_entry: list of tuples shaped like (channel,count,cost)
#@return: 
def get_CAC(list_of_entry):
    output_user = dict()
    output_cost = dict()
    CAC = dict()
    for i in list_of_entry:
        if i[0] == None:
            continue
        for j in range(len(i[0])):
            channel = i[0][j]
            if channel not in output_user.keys():
                output_user[channel] = i[1][j]
                output_cost[channel] = i[2][j] 
            else:
                output_user[channel] += i[1][j]
                output_cost[channel] += i[2][j] 
                
    for i in output_user.keys():
        if output_user[i] != None:
            CAC[i] = (output_cost[i]/output_user[i])
        print(i,'count',output_user[i],'cost',output_cost[i],'CAC',CAC[i] ,sep = ' ')
    return output_user, output_cost, CAC

# %%
output_user, output_cost, CAC = get_CAC(list_of_entry_last)
# Out:
# social count 352 cost 126950 CAC 360.65340909090907
# direct count 613 cost 0 CAC 0.0
# email count 323 cost 125400 CAC 388.2352941176471
# organic_search count 662 cost 0 CAC 0.0
# display count 406 cost 145150 CAC 357.51231527093597
# referral count 10 cost 4500 CAC 450.0
# paid_search count 12 cost 4450 CAC 370.8333333333333

# %% [markdown]
# ## Position based

# %%
# This function takes a row accessed by dataframe's iloc, and returns the position-based cost
#@param: entry: a single entry of the dataframe. Must be a return value from the iloc function
#@return: a tuple. the position_based contact. None if not applicable. And another attribute is cost
def find_position_based(entry):
    if entry['convert_TF']:
        if entry['touch_5'] == 'none':
            if entry['touch_4'] == 'none':
                if entry['touch_3'] == 'none':
                    if entry['touch_2'] == 'none':
                        if entry['touch_1'] == 'none':
                            return None,[0],[0]
                        else:
                            list_channel = list()
                            list_number = list()
                            list_channel.append(entry['touch_1'])
                            list_number.append(1)
                            return list_channel,list_number,[entry[entry['touch_1']]]
                    else:
                        list_channel = list()
                        list_number = list()
                        list_channel.append(entry['touch_2'])
                        list_channel.append(entry['touch_1'])
                        list_number.append(0.5)
                        list_number.append(0.5)
                        cost = [entry[entry['touch_2']],entry[entry['touch_1']]]
                        return list_channel,list_number,cost
                else:
                    list_channel = list()
                    list_number = list()
                    list_channel.append(entry['touch_3'])
                    list_channel.append(entry['touch_2'])
                    list_channel.append(entry['touch_1'])
                    list_number.append(0.4)
                    list_number.append(0.2)
                    list_number.append(0.4)
                    cost = [entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
                    return list_channel,list_number,cost
            else:
                list_channel = list()
                list_number = list()
                list_channel.append(entry['touch_4'])
                list_channel.append(entry['touch_3'])
                list_channel.append(entry['touch_2'])
                list_channel.append(entry['touch_1'])
                list_number.append(0.4)
                list_number.append(0.1)
                list_number.append(0.1)
                list_number.append(0.4)
                cost = [entry[entry['touch_4']],entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
                return list_channel,list_number,cost
        else:
            list_channel = list()
            list_number = list()
            list_channel.append(entry['touch_5'])
            list_channel.append(entry['touch_4'])
            list_channel.append(entry['touch_3'])
            list_channel.append(entry['touch_2'])
            list_channel.append(entry['touch_1'])
            list_number.append(0.4)
            list_number.append(0.066)
            list_number.append(0.066)
            list_number.append(0.066)
            list_number.append(0.4)
            cost = [entry[entry['touch_5']],entry[entry['touch_4']],entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
            return list_channel,list_number,cost
    else:
        return None,[0],[0]

# %%
list_of_entry_position_based = list()
for i in range(len(df)):
    entry = df1.iloc[i,:]
    list_of_entry_position_based.append(find_position_based(entry))

# %%
list_of_entry_position_based
# Out:
# [(['social', 'direct', 'email'], [0.4, 0.2, 0.4], [50, 0, 50]),
#  (['organic_search', 'direct', 'social'], [0.4, 0.2, 0.4], [0, 0, 50]),
#  (['social', 'display', 'organic_search'], [0.4, 0.2, 0.4], [50, 50, 0]),
#  (['direct', 'social'], [0.5, 0.5], [0, 50]),
#  (['direct', 'display', 'social'], [0.4, 0.2, 0.4], [0, 50, 50]),
#  (['display', 'social'], [0.5, 0.5], [50, 50]),
#  (['social'], [1], [50]),
#  (['direct', 'social', 'display', 'organic_search'],
#   [0.4, 0.1, 0.1, 0.4],
#   [0, 50, 50, 0]),
#  (['social'], [1], [50]),
#  (['social'], [1], [50]),
#  (['organic_search', 'email', 'social'], [0.4, 0.2, 0.4], [0, 50, 50]),
#  (['organic_search', 'social'], [0.5, 0.5], [0, 50]),
#  (['social', 'organic_search', 'direct'], [0.4, 0.2, 0.4], [50, 0, 0]),
#  (['organic_search', 'social', 'direct'], [0.4, 0.2, 0.4], [0, 50, 0]),
#  (['social', 'display'], [0.5, 0.5], [50, 50]),
#  (['direct', 'display', 'social'], [0.4, 0.2, 0.4], [0, 50, 50]),
#  (['social', 'organic_search'], [0.5, 0.5], [50, 0]),
#  (['direct', 'social', 'display'], [0.4, 0.2, 0.4], [0, 50, 50]),
#  (['social', 'display'], [0.5, 0.5], [50, 50]),
#  (['organic_search', 'direct', 'social'], [0.4, 0.2, 0.4], [0, 0, 50]),
#  (['organic_search', 'display', 'email', 'social'],
#   [0.4, 0.1, 0.1, 0.4],
#   [0, 50, 50, 50]),
#  (['email', 'organic_search', 'social'], [0.4, 0.2, 0.4], [50, 0, 50]),
#  (['direct', 'display', 'organic_search', 'email', 'social'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 50, 0, 50, 50]),
#  (['social', 'direct', 'email'], [0.4, 0.2, 0.4], [50, 0, 50]),
#  (['email', 'social', 'direct'], [0.4, 0.2, 0.4], [50, 50, 0]),
#  (['organic_search', 'display', 'direct', 'social'],
#   [0.4, 0.1, 0.1, 0.4],
#   [0, 50, 0, 50]),
#  (['display', 'social', 'organic_search'], [0.4, 0.2, 0.4], [50, 50, 0]),
#  (['social', 'direct', 'email', 'organic_search', 'display'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [50, 0, 50, 0, 50]),
#  (['social', 'direct', 'organic_search'], [0.4, 0.2, 0.4], [50, 0, 0]),
#  (['direct', 'organic_search', 'display', 'social', 'email'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 0, 50, 50, 50]),
#  (['direct', 'organic_search', 'email', 'social', 'display'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 0, 50, 50, 50]),
#  (['organic_search', 'direct', 'social'], [0.4, 0.2, 0.4], [0, 0, 50]),
#  (['display', 'social', 'email'], [0.4, 0.2, 0.4], [50, 50, 50]),
#  (['social', 'direct'], [0.5, 0.5], [50, 0]),
#  (['display', 'social', 'direct'], [0.4, 0.2, 0.4], [50, 50, 0]),
#  (['social'], [1], [50]),
#  (['display', 'social', 'organic_search'], [0.4, 0.2, 0.4], [50, 50, 0]),
#  (['direct', 'social', 'email'], [0.4, 0.2, 0.4], [0, 50, 50]),
#  (['email', 'organic_search', 'social', 'display', 'direct'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [50, 0, 50, 50, 0]),
#  (['organic_search', 'social', 'email', 'direct', 'display'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 50, 50, 0, 50]),
#  (['organic_search', 'direct', 'social'], [0.4, 0.2, 0.4], [0, 0, 50]),
#  (['organic_search', 'social', 'direct', 'display', 'email'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 50, 0, 50, 50]),
#  (['organic_search', 'direct', 'social', 'email'],
#   [0.4, 0.1, 0.1, 0.4],
#   [0, 0, 50, 50]),
#  (['direct', 'email', 'social', 'display', 'organic_search'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 50, 50, 50, 0]),
#  (['display', 'social'], [0.5, 0.5], [50, 50]),
#  (['social'], [1], [50]),
#  (['social', 'display'], [0.5, 0.5], [50, 50]),
#  (['social'], [1], [50]),
#  (['social', 'organic_search', 'display'], [0.4, 0.2, 0.4], [50, 0, 50]),
#  (['social', 'direct', 'email', 'display', 'organic_search'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [50, 0, 50, 50, 0]),
#  (['social', 'organic_search', 'direct'], [0.4, 0.2, 0.4], [50, 0, 0]),
#  (['organic_search', 'email', 'display', 'social', 'direct'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 50, 50, 50, 0]),
#  (['display', 'social', 'organic_search'], [0.4, 0.2, 0.4], [50, 50, 0]),
#  (['display', 'social', 'organic_search', 'direct'],
#   [0.4, 0.1, 0.1, 0.4],
#   [50, 50, 0, 0]),
#  (['email', 'direct', 'display', 'social'],
#   [0.4, 0.1, 0.1, 0.4],
#   [50, 0, 50, 50]),
#  (['social', 'direct'], [0.5, 0.5], [50, 0]),
#  (['organic_search', 'direct', 'social', 'display'],
#   [0.4, 0.1, 0.1, 0.4],
#   [0, 0, 50, 50]),
#  (['display', 'organic_search', 'social'], [0.4, 0.2, 0.4], [50, 0, 50]),
#  (['email', 'direct', 'display', 'social', 'organic_search'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [50, 0, 50, 50, 0]),
#  (['display', 'social'], [0.5, 0.5], [50, 50]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  ...]

# %%
output_user, output_cost, CAC = get_CAC(list_of_entry_position_based)
# Out:
# social count 349.1979999999967 cost 126950 CAC 363.5473284497655
# direct count 580.7619999999931 cost 0 CAC 0.0
# email count 340.48199999999764 cost 125400 CAC 368.3014080039499
# organic_search count 668.9319999999938 cost 0 CAC 0.0
# display count 416.59599999999546 cost 145150 CAC 348.4190918779863
# referral count 10.298000000000002 cost 4500 CAC 436.97805399106613
# paid_search count 11.230000000000004 cost 4450 CAC 396.26001780943886

# %% [markdown]
# ## Linear Method

# %%
# This function takes a row accessed by dataframe's iloc, and returns the position-based cost
#@param: entry: a single entry of the dataframe. Must be a return value from the iloc function
#@return: a tuple. the position_based contact. None if not applicable. And another attribute is cost
def find_linear(entry):
    if entry['convert_TF']:
        if entry['touch_5'] == 'none':
            if entry['touch_4'] == 'none':
                if entry['touch_3'] == 'none':
                    if entry['touch_2'] == 'none':
                        if entry['touch_1'] == 'none':
                            return None,[0],[0]
                        else:
                            list_channel = list()
                            list_number = list()
                            list_channel.append(entry['touch_1'])
                            list_number.append(1)
                            return list_channel,list_number,[entry[entry['touch_1']]]
                    else:
                        list_channel = list()
                        list_number = list()
                        list_channel.append(entry['touch_2'])
                        list_channel.append(entry['touch_1'])
                        list_number.append(0.5)
                        list_number.append(0.5)
                        cost = [entry[entry['touch_2']],entry[entry['touch_1']]]
                        return list_channel,list_number,cost
                else:
                    list_channel = list()
                    list_number = list()
                    list_channel.append(entry['touch_3'])
                    list_channel.append(entry['touch_2'])
                    list_channel.append(entry['touch_1'])
                    list_number.append(0.33)
                    list_number.append(0.33)
                    list_number.append(0.33)
                    cost = [entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
                    return list_channel,list_number,cost
            else:
                list_channel = list()
                list_number = list()
                list_channel.append(entry['touch_4'])
                list_channel.append(entry['touch_3'])
                list_channel.append(entry['touch_2'])
                list_channel.append(entry['touch_1'])
                list_number.append(0.25)
                list_number.append(0.25)
                list_number.append(0.25)
                list_number.append(0.25)
                cost = [entry[entry['touch_4']],entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
                return list_channel,list_number,cost
        else:
            list_channel = list()
            list_number = list()
            list_channel.append(entry['touch_5'])
            list_channel.append(entry['touch_4'])
            list_channel.append(entry['touch_3'])
            list_channel.append(entry['touch_2'])
            list_channel.append(entry['touch_1'])
            list_number.append(0.2)
            list_number.append(0.2)
            list_number.append(0.2)
            list_number.append(0.2)
            list_number.append(0.2)
            cost = [entry[entry['touch_5']],entry[entry['touch_4']],entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
            return list_channel,list_number,cost
    else:
        return None,[0],[0]

# %%
list_of_entry_linear = list()
for i in range(len(df)):
    entry = df1.iloc[i,:]
    list_of_entry_linear.append(find_linear(entry))

# %%
output_user, output_cost, CAC = get_CAC(list_of_entry_linear)
# Out:
# social: count: 351.73999999999825: cost: 126950: CAC: 360.91999772559456
# direct: count: 579.9999999999997: cost: 0: CAC: 0.0
# email: count: 336.22999999999865: cost: 125400: CAC: 372.958986408115
# organic_search: count: 664.6900000000062: cost: 0: CAC: 0.0
# display: count: 415.08999999999696: cost: 145150: CAC: 349.68320123347
# referral: count: 10.24: cost: 4500: CAC: 439.453125
# paid_search: count: 10.52: cost: 4450: CAC: 423.00380228136885

# %% [markdown]
# ## Time Decay

# %%
# This function takes a row accessed by dataframe's iloc, and returns the position-based cost
#@param: entry: a single entry of the dataframe. Must be a return value from the iloc function
#@return: a tuple. the position_based contact. None if not applicable. And another attribute is cost
def find_decay(entry):
    if entry['convert_TF']:
        if entry['touch_5'] == 'none':
            if entry['touch_4'] == 'none':
                if entry['touch_3'] == 'none':
                    if entry['touch_2'] == 'none':
                        if entry['touch_1'] == 'none':
                            return None,[0],[0]
                        else:
                            list_channel = list()
                            list_number = list()
                            list_channel.append(entry['touch_1'])
                            list_number.append(1)
                            return list_channel,list_number,[entry[entry['touch_1']]]
                    else:
                        list_channel = list()
                        list_number = list()
                        list_channel.append(entry['touch_2'])
                        list_channel.append(entry['touch_1'])
                        list_number.append(0.4)
                        list_number.append(0.6)
                        cost = [entry[entry['touch_2']],entry[entry['touch_1']]]
                        return list_channel,list_number,cost
                else:
                    list_channel = list()
                    list_number = list()
                    list_channel.append(entry['touch_3'])
                    list_channel.append(entry['touch_2'])
                    list_channel.append(entry['touch_1'])
                    list_number.append(0.2)
                    list_number.append(0.3)
                    list_number.append(0.5)
                    cost = [entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
                    return list_channel,list_number,cost
            else:
                list_channel = list()
                list_number = list()
                list_channel.append(entry['touch_4'])
                list_channel.append(entry['touch_3'])
                list_channel.append(entry['touch_2'])
                list_channel.append(entry['touch_1'])
                list_number.append(0.1)
                list_number.append(0.2)
                list_number.append(0.3)
                list_number.append(0.4)
                cost = [entry[entry['touch_4']],entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
                return list_channel,list_number,cost
        else:
            list_channel = list()
            list_number = list()
            list_channel.append(entry['touch_5'])
            list_channel.append(entry['touch_4'])
            list_channel.append(entry['touch_3'])
            list_channel.append(entry['touch_2'])
            list_channel.append(entry['touch_1'])
            list_number.append(0.045)
            list_number.append(0.08)
            list_number.append(0.125)
            list_number.append(0.25)
            list_number.append(0.5)
            cost = [entry[entry['touch_5']],entry[entry['touch_4']],entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
            return list_channel,list_number,cost
    else:
        return None,[0],[0]

# %%
list_of_entry_decay = list()
for i in range(len(df)):
    entry = df1.iloc[i,:]
    list_of_entry_decay.append(find_decay(entry))

# %%
output_user, output_cost, CAC = get_CAC(list_of_entry_decay)
# Out:
# social: count: 350.66000000000014: cost: 126950: CAC: 362.0315975588888
# direct: count: 572.9849999999998: cost: 0: CAC: 0.0
# email: count: 346.16500000000036: cost: 125400: CAC: 362.2549940057483
# organic_search: count: 666.6899999999991: cost: 0: CAC: 0.0
# display: count: 420.74999999999915: cost: 145150: CAC: 344.97920380273393
# referral: count: 10.399999999999999: cost: 4500: CAC: 432.69230769230774
# paid_search: count: 10.349999999999994: cost: 4450: CAC: 429.95169082125625

# %%
df1_tier1 = df1.loc[df1['tier'] == 1]
df1_tier2 = df1.loc[df1['tier'] == 2]
df1_tier3 = df1.loc[df1['tier'] == 3]

# %%
list_of_entry_position_based = list()
for i in range(len(df1_tier1)):
    entry = df1_tier1.iloc[i,:]
    list_of_entry_position_based.append(find_position_based(entry))
output_user_tier1, output_cost_tier1, CAC_tier1 = get_CAC(list_of_entry_position_based)
# Out:
# social count 65.81000000000002 cost 10850 CAC 164.86856100896517
# direct count 105.68200000000017 cost 0 CAC 0.0
# email count 64.51599999999999 cost 10100 CAC 156.55031310062623
# organic_search count 118.08200000000039 cost 0 CAC 0.0
# display count 83.37800000000017 cost 13200 CAC 158.31514308330702
# referral count 1.4 cost 200 CAC 142.85714285714286
# paid_search count 2.032 cost 350 CAC 172.24409448818898

# %%
list_of_entry_position_based = list()
for i in range(len(df1_tier2)):
    entry = df1_tier2.iloc[i,:]
    list_of_entry_position_based.append(find_position_based(entry))
output_user_tier2, output_cost_tier2, CAC_tier2 = get_CAC(list_of_entry_position_based)
# Out:
# direct count 183.5580000000005 cost 0 CAC 0.0
# email count 110.70200000000042 cost 36400 CAC 328.8106809271726
# social count 126.19400000000051 cost 41700 CAC 330.44360270694193
# display count 158.26200000000068 cost 47500 CAC 300.1352188143698
# organic_search count 226.7280000000007 cost 0 CAC 0.0
# paid_search count 3.266 cost 1100 CAC 336.80342927127987
# referral count 2.098 cost 1000 CAC 476.6444232602479

# %%
list_of_entry_position_based = list()
for i in range(len(df1_tier3)):
    entry = df1_tier3.iloc[i,:]
    list_of_entry_position_based.append(find_position_based(entry))
output_user_tier3, output_cost_tier3, CAC_tier3 = get_CAC(list_of_entry_position_based)
# Out:
# direct count 291.52199999999954 cost 0 CAC 0.0
# display count 174.9560000000007 cost 84450 CAC 482.6927913303897
# email count 165.26400000000052 cost 78900 CAC 477.4179494626764
# organic_search count 324.12199999999837 cost 0 CAC 0.0
# social count 157.19400000000064 cost 74400 CAC 473.3005076529619
# referral count 6.800000000000001 cost 3300 CAC 485.2941176470588
# paid_search count 5.9319999999999995 cost 3000 CAC 505.7316250842886

# %%
CAC_tier1
# Out:
# {'social': 164.86856100896517,
#  'direct': 0.0,
#  'email': 156.55031310062623,
#  'organic_search': 0.0,
#  'display': 158.31514308330702,
#  'referral': 142.85714285714286,
#  'paid_search': 172.24409448818898}

# %%
CAC_tier2
# Out:
# {'direct': 0.0,
#  'email': 328.8106809271726,
#  'social': 330.44360270694193,
#  'display': 300.1352188143698,
#  'organic_search': 0.0,
#  'paid_search': 336.80342927127987,
#  'referral': 476.6444232602479}

# %%
CAC_tier3
# Out:
# {'direct': 0.0,
#  'display': 482.6927913303897,
#  'email': 477.4179494626764,
#  'organic_search': 0.0,
#  'social': 473.3005076529619,
#  'referral': 485.2941176470588,
#  'paid_search': 505.7316250842886}

# %%
for i in CAC_tier1.keys():
    marginal_2_1 = CAC_tier2[i] - CAC_tier1[i]
    marginal_3_2 = CAC_tier3[i] - CAC_tier2[i]
    print(i)
    print('marginal_2_1 ',marginal_2_1 ,sep = ': ')
    print('marginal_3_2 ',marginal_3_2 ,sep = ': ')
# Out:
# social
# marginal_2_1 : 165.57504169797676
# marginal_3_2 : 142.85690494602
# direct
# marginal_2_1 : 0.0
# marginal_3_2 : 0.0
# email
# marginal_2_1 : 172.26036782654637
# marginal_3_2 : 148.6072685355038
# organic_search
# marginal_2_1 : 0.0
# marginal_3_2 : 0.0
# display
# marginal_2_1 : 141.8200757310628
# marginal_3_2 : 182.5575725160199
# referral
# marginal_2_1 : 333.787280403105
# marginal_3_2 : 8.649694386810893
# paid_search
# marginal_2_1 : 164.5593347830909
# marginal_3_2 : 168.92819581300876

# %%
[['social', 'direct', 'email'], 
 ['organic_search', 'direct', 'social'],
 ['social', 'display', 'organic_search']]
# Out:
# [['social', 'direct', 'email'],
#  ['organic_search', 'direct', 'social'],
#  ['social', 'display', 'organic_search']]

# %%
email 1
social 1
organic_search 1

# %%
email 0.4
direct 0.4
display 0.2
social 1.2 
organic 0.8
