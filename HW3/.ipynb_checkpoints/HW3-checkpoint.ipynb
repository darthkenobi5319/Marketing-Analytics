# %%
import numpy as np
import pandas as pd
import json

# %%
df = pd.read_csv("attribution_allocation_student_data.csv")

# %%
df.head()
# Out:
#    convert_TF         touch_1  touch_2         touch_3 touch_4 touch_5  tier
# 0        True           email   direct          social     NaN     NaN     1
# 1        True          social   direct  organic_search     NaN     NaN     1
# 2        True  organic_search  display          social     NaN     NaN     1
# 3        True          social   direct             NaN     NaN     NaN     1
# 4        True          social  display          direct     NaN     NaN     1

# %%
df.tier.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df = df.fillna('none')

# %%
df.head()
# Out:
#    convert_TF         touch_1  touch_2         touch_3 touch_4 touch_5  tier
# 0        True           email   direct          social    none    none     1
# 1        True          social   direct  organic_search    none    none     1
# 2        True  organic_search  display          social    none    none     1
# 3        True          social   direct            none    none    none     1
# 4        True          social  display          direct    none    none     1

# %%
df_channel = pd.read_csv("channel_spend_student_data.csv")

# %%
df_channel = df_channel.drop(3)

# %%
newdf = list()
for i in range(len(df_channel)):
    temp = json.loads(df_channel['spend by channel'][i].replace("\'", "\""))
    temp['tier'] = (i+1)
    newdf.append(temp)
newdf
# Out:
# [{'social': 50,
#   'organic_search': 0,
#   'referral': 50,
#   'email': 50,
#   'paid_search': 50,
#   'display': 50,
#   'direct': 0,
#   'tier': 1},
#  {'social': 100,
#   'organic_search': 0,
#   'referral': 100,
#   'email': 100,
#   'paid_search': 100,
#   'display': 100,
#   'direct': 0,
#   'tier': 2},
#  {'social': 150,
#   'organic_search': 0,
#   'referral': 150,
#   'email': 150,
#   'paid_search': 150,
#   'display': 150,
#   'direct': 0,
#   'tier': 3}]

# %%
df_channel = pd.DataFrame(newdf)

# %%
df1 = pd.merge(df, df_channel,how='left', on='tier')

# %%
df1.head()
# Out:
#    convert_TF         touch_1  touch_2         touch_3 touch_4 touch_5  tier  \
# 0        True           email   direct          social    none    none     1
# 1        True          social   direct  organic_search    none    none     1
# 2        True  organic_search  display          social    none    none     1
# 3        True          social   direct            none    none    none     1
# 4        True          social  display          direct    none    none     1
#
#    social  organic_search  referral  email  paid_search  display  direct
# 0      50               0        50     50           50       50       0
# 1      50               0        50     50           50       50       0
# 2      50               0        50     50           50       50       0
# 3      50               0        50     50           50       50       0
# 4      50               0        50     50           50       50       0

# %%
df.iloc[0,:]['touch_1']
# Out:
# 'email'

# %%
len(df)
# Out:
# 218412

# %%
# This function takes a row accessed by dataframe's iloc, and returns the last contact
#@param: entry: a single entry of the dataframe. Must be a return value from the iloc function
#@return: a tuple. the last contact. None if not applicable. second attribute is count, and another attribute is cost
def find_last_contact(entry):
    if entry['convert_TF']:
        if entry['touch_5'] == 'none':
            if entry['touch_4'] == 'none':
                if entry['touch_3'] == 'none':
                    if entry['touch_2'] == 'none':
                        if entry['touch_1'] == 'none':
                            return None,[0],[0]
                        else:
                            list_channel = list()
                            list_number = list()
                            list_channel.append(entry['touch_1'])
                            list_number.append(1)
                            return list_channel,list_number,[entry[entry['touch_1']]]
                    else:
                        list_channel = list()
                        list_number = list()
                        list_channel.append(entry['touch_2'])
                        list_number.append(1)
                        return list_channel,list_number,[entry[entry['touch_2']]]
                else:
                    list_channel = list()
                    list_number = list()
                    list_channel.append(entry['touch_3'])
                    list_number.append(1)
                    return list_channel,list_number,[entry[entry['touch_3']]]
            else:
                list_channel = list()
                list_number = list()
                list_channel.append(entry['touch_4'])
                list_number.append(1)
                return list_channel,list_number,[entry[entry['touch_4']]]
        else:
            list_channel = list()
            list_number = list()
            list_channel.append(entry['touch_5'])
            list_number.append(1)
            return list_channel,list_number,[entry[entry['touch_5']]]
    else:
        return None,[0],[0]

# %%
list_of_entry_last_user = list()
list_of_entry_last = list()
for i in range(len(df)):
    entry = df1.iloc[i,:]
    list_of_entry_last.append(find_last_contact(entry))

# %%
list_of_entry_last
# Out:
# [(['social'], [1], [50]),
#  (['organic_search'], [1], [0]),
#  (['social'], [1], [50]),
#  (['direct'], [1], [0]),
#  (['direct'], [1], [0]),
#  (['display'], [1], [50]),
#  (['social'], [1], [50]),
#  (['direct'], [1], [0]),
#  (['social'], [1], [50]),
#  (['social'], [1], [50]),
#  (['organic_search'], [1], [0]),
#  (['organic_search'], [1], [0]),
#  (['social'], [1], [50]),
#  (['organic_search'], [1], [0]),
#  (['social'], [1], [50]),
#  (['direct'], [1], [0]),
#  (['social'], [1], [50]),
#  (['direct'], [1], [0]),
#  (['social'], [1], [50]),
#  (['organic_search'], [1], [0]),
#  (['organic_search'], [1], [0]),
#  (['email'], [1], [50]),
#  (['direct'], [1], [0]),
#  (['social'], [1], [50]),
#  (['email'], [1], [50]),
#  (['organic_search'], [1], [0]),
#  (['display'], [1], [50]),
#  (['social'], [1], [50]),
#  (['social'], [1], [50]),
#  (['direct'], [1], [0]),
#  (['direct'], [1], [0]),
#  (['organic_search'], [1], [0]),
#  (['display'], [1], [50]),
#  (['social'], [1], [50]),
#  (['display'], [1], [50]),
#  (['social'], [1], [50]),
#  (['display'], [1], [50]),
#  (['direct'], [1], [0]),
#  (['email'], [1], [50]),
#  (['organic_search'], [1], [0]),
#  (['organic_search'], [1], [0]),
#  (['organic_search'], [1], [0]),
#  (['organic_search'], [1], [0]),
#  (['direct'], [1], [0]),
#  (['display'], [1], [50]),
#  (['social'], [1], [50]),
#  (['social'], [1], [50]),
#  (['social'], [1], [50]),
#  (['social'], [1], [50]),
#  (['social'], [1], [50]),
#  (['social'], [1], [50]),
#  (['organic_search'], [1], [0]),
#  (['display'], [1], [50]),
#  (['display'], [1], [50]),
#  (['email'], [1], [50]),
#  (['social'], [1], [50]),
#  (['organic_search'], [1], [0]),
#  (['display'], [1], [50]),
#  (['email'], [1], [50]),
#  (['display'], [1], [50]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  ...]

# %%
# This function takes a list of entry, each element is a tuple shaped like (channel,count,cost)
# And prints out count, cost, and CAC
#@param: list_of_entry: list of tuples shaped like (channel,count,cost)
#@return: 
def get_CAC(list_of_entry):
    output_user = dict()
    output_cost = dict()
    for i in list_of_entry:
        if i[0] == None:
            continue
        for j in range(len(i[0])):
            channel = i[0][j]
            if channel not in output_user.keys():
                output_user[channel] = i[1][j]
                output_cost[channel] = i[2][j] *  i[1][j]
            else:
                output_user[channel] += i[1][j]
                output_cost[channel] += i[2][j] *  i[1][j]
                
    for i in output_user.keys():
        if output_user[i] != None:
            CAC = output_cost[i]/output_user[i]
        print(i,'count',output_user[i],'cost',output_cost[i],'CAC',CAC,sep = ': ')
    return

# %%
get_CAC(list_of_entry_last)
# Out:
# social: count: 352: cost: 40550: CAC: 115.19886363636364
# organic_search: count: 662: cost: 0: CAC: 0.0
# direct: count: 613: cost: 0: CAC: 0.0
# display: count: 406: cost: 45750: CAC: 112.6847290640394
# email: count: 323: cost: 37000: CAC: 114.55108359133126
# paid_search: count: 12: cost: 1500: CAC: 125.0
# referral: count: 10: cost: 1300: CAC: 130.0

# %%
# This function takes a row accessed by dataframe's iloc, and returns the position-based cost
#@param: entry: a single entry of the dataframe. Must be a return value from the iloc function
#@return: a tuple. the position_based contact. None if not applicable. And another attribute is cost
def find_position_based(entry):
    if entry['convert_TF']:
        if entry['touch_5'] == 'none':
            if entry['touch_4'] == 'none':
                if entry['touch_3'] == 'none':
                    if entry['touch_2'] == 'none':
                        if entry['touch_1'] == 'none':
                            return None,[0],[0]
                        else:
                            list_channel = list()
                            list_number = list()
                            list_channel.append(entry['touch_1'])
                            list_number.append(1)
                            return list_channel,list_number,[entry[entry['touch_1']]]
                    else:
                        list_channel = list()
                        list_number = list()
                        list_channel.append(entry['touch_2'])
                        list_channel.append(entry['touch_1'])
                        list_number.append(0.5)
                        list_number.append(0.5)
                        cost = [entry[entry['touch_2']],entry[entry['touch_1']]]
                        return list_channel,list_number,cost
                else:
                    list_channel = list()
                    list_number = list()
                    list_channel.append(entry['touch_3'])
                    list_channel.append(entry['touch_2'])
                    list_channel.append(entry['touch_1'])
                    list_number.append(0.4)
                    list_number.append(0.1)
                    list_number.append(0.4)
                    cost = [entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
                    return list_channel,list_number,cost
            else:
                list_channel = list()
                list_number = list()
                list_channel.append(entry['touch_4'])
                list_channel.append(entry['touch_3'])
                list_channel.append(entry['touch_2'])
                list_channel.append(entry['touch_1'])
                list_number.append(0.4)
                list_number.append(0.1)
                list_number.append(0.1)
                list_number.append(0.4)
                cost = [entry[entry['touch_4']],entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
                return list_channel,list_number,cost
        else:
            list_channel = list()
            list_number = list()
            list_channel.append(entry['touch_5'])
            list_channel.append(entry['touch_4'])
            list_channel.append(entry['touch_3'])
            list_channel.append(entry['touch_2'])
            list_channel.append(entry['touch_1'])
            list_number.append(0.4)
            list_number.append(0.066)
            list_number.append(0.066)
            list_number.append(0.066)
            list_number.append(0.4)
            cost = [entry[entry['touch_5']],entry[entry['touch_4']],entry[entry['touch_3']],entry[entry['touch_2']],entry[entry['touch_1']]]
            return list_channel,list_number,cost
    else:
        return None,[0],[0]

# %%
list_of_entry_position_based = list()
for i in range(len(df)):
    entry = df1.iloc[i,:]
    list_of_entry_position_based.append(find_position_based(entry))

# %%
 list_of_entry_position_based
# Out:
# [(['social', 'direct', 'email'], [0.4, 0.1, 0.4], [50, 0, 50]),
#  (['organic_search', 'direct', 'social'], [0.4, 0.1, 0.4], [0, 0, 50]),
#  (['social', 'display', 'organic_search'], [0.4, 0.1, 0.4], [50, 50, 0]),
#  (['direct', 'social'], [0.5, 0.5], [0, 50]),
#  (['direct', 'display', 'social'], [0.4, 0.1, 0.4], [0, 50, 50]),
#  (['display', 'social'], [0.5, 0.5], [50, 50]),
#  (['social'], [1], [50]),
#  (['direct', 'social', 'display', 'organic_search'],
#   [0.4, 0.1, 0.1, 0.4],
#   [0, 50, 50, 0]),
#  (['social'], [1], [50]),
#  (['social'], [1], [50]),
#  (['organic_search', 'email', 'social'], [0.4, 0.1, 0.4], [0, 50, 50]),
#  (['organic_search', 'social'], [0.5, 0.5], [0, 50]),
#  (['social', 'organic_search', 'direct'], [0.4, 0.1, 0.4], [50, 0, 0]),
#  (['organic_search', 'social', 'direct'], [0.4, 0.1, 0.4], [0, 50, 0]),
#  (['social', 'display'], [0.5, 0.5], [50, 50]),
#  (['direct', 'display', 'social'], [0.4, 0.1, 0.4], [0, 50, 50]),
#  (['social', 'organic_search'], [0.5, 0.5], [50, 0]),
#  (['direct', 'social', 'display'], [0.4, 0.1, 0.4], [0, 50, 50]),
#  (['social', 'display'], [0.5, 0.5], [50, 50]),
#  (['organic_search', 'direct', 'social'], [0.4, 0.1, 0.4], [0, 0, 50]),
#  (['organic_search', 'display', 'email', 'social'],
#   [0.4, 0.1, 0.1, 0.4],
#   [0, 50, 50, 50]),
#  (['email', 'organic_search', 'social'], [0.4, 0.1, 0.4], [50, 0, 50]),
#  (['direct', 'display', 'organic_search', 'email', 'social'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 50, 0, 50, 50]),
#  (['social', 'direct', 'email'], [0.4, 0.1, 0.4], [50, 0, 50]),
#  (['email', 'social', 'direct'], [0.4, 0.1, 0.4], [50, 50, 0]),
#  (['organic_search', 'display', 'direct', 'social'],
#   [0.4, 0.1, 0.1, 0.4],
#   [0, 50, 0, 50]),
#  (['display', 'social', 'organic_search'], [0.4, 0.1, 0.4], [50, 50, 0]),
#  (['social', 'direct', 'email', 'organic_search', 'display'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [50, 0, 50, 0, 50]),
#  (['social', 'direct', 'organic_search'], [0.4, 0.1, 0.4], [50, 0, 0]),
#  (['direct', 'organic_search', 'display', 'social', 'email'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 0, 50, 50, 50]),
#  (['direct', 'organic_search', 'email', 'social', 'display'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 0, 50, 50, 50]),
#  (['organic_search', 'direct', 'social'], [0.4, 0.1, 0.4], [0, 0, 50]),
#  (['display', 'social', 'email'], [0.4, 0.1, 0.4], [50, 50, 50]),
#  (['social', 'direct'], [0.5, 0.5], [50, 0]),
#  (['display', 'social', 'direct'], [0.4, 0.1, 0.4], [50, 50, 0]),
#  (['social'], [1], [50]),
#  (['display', 'social', 'organic_search'], [0.4, 0.1, 0.4], [50, 50, 0]),
#  (['direct', 'social', 'email'], [0.4, 0.1, 0.4], [0, 50, 50]),
#  (['email', 'organic_search', 'social', 'display', 'direct'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [50, 0, 50, 50, 0]),
#  (['organic_search', 'social', 'email', 'direct', 'display'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 50, 50, 0, 50]),
#  (['organic_search', 'direct', 'social'], [0.4, 0.1, 0.4], [0, 0, 50]),
#  (['organic_search', 'social', 'direct', 'display', 'email'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 50, 0, 50, 50]),
#  (['organic_search', 'direct', 'social', 'email'],
#   [0.4, 0.1, 0.1, 0.4],
#   [0, 0, 50, 50]),
#  (['direct', 'email', 'social', 'display', 'organic_search'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 50, 50, 50, 0]),
#  (['display', 'social'], [0.5, 0.5], [50, 50]),
#  (['social'], [1], [50]),
#  (['social', 'display'], [0.5, 0.5], [50, 50]),
#  (['social'], [1], [50]),
#  (['social', 'organic_search', 'display'], [0.4, 0.1, 0.4], [50, 0, 50]),
#  (['social', 'direct', 'email', 'display', 'organic_search'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [50, 0, 50, 50, 0]),
#  (['social', 'organic_search', 'direct'], [0.4, 0.1, 0.4], [50, 0, 0]),
#  (['organic_search', 'email', 'display', 'social', 'direct'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [0, 50, 50, 50, 0]),
#  (['display', 'social', 'organic_search'], [0.4, 0.1, 0.4], [50, 50, 0]),
#  (['display', 'social', 'organic_search', 'direct'],
#   [0.4, 0.1, 0.1, 0.4],
#   [50, 50, 0, 0]),
#  (['email', 'direct', 'display', 'social'],
#   [0.4, 0.1, 0.1, 0.4],
#   [50, 0, 50, 50]),
#  (['social', 'direct'], [0.5, 0.5], [50, 0]),
#  (['organic_search', 'direct', 'social', 'display'],
#   [0.4, 0.1, 0.1, 0.4],
#   [0, 0, 50, 50]),
#  (['display', 'organic_search', 'social'], [0.4, 0.1, 0.4], [50, 0, 50]),
#  (['email', 'direct', 'display', 'social', 'organic_search'],
#   [0.4, 0.066, 0.066, 0.066, 0.4],
#   [50, 0, 50, 50, 0]),
#  (['display', 'social'], [0.5, 0.5], [50, 50]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  (None, [0], [0]),
#  ...]

# %%
get_CAC(list_of_entry_position_based)
# Out:
# social: count: 334.3979999999984: cost: 37809.00000000011: CAC: 113.06586761882635
# direct: count: 557.8619999999958: cost: 0.0: CAC: 0.0
# email: count: 325.68199999999945: cost: 37380.60000000008: CAC: 114.77637695666368
# organic_search: count: 641.4319999999951: cost: 0.0: CAC: 0.0
# display: count: 402.59599999999745: cost: 44673.50000000009: CAC: 110.96359626027176
# referral: count: 9.698: cost: 1234.8: CAC: 127.32522169519487
# paid_search: count: 10.930000000000005: cost: 1288.0: CAC: 117.8408051235132
